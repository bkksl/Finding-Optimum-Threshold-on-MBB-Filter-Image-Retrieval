# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import h5py
import numpy as np

module_path = os.path.join("/content/drive/MyDrive", "TEZ_ML_PART")
if module_path not in sys.path:
    sys.path.append(module_path)

# importing the module
try:
    from two_vgg_feature_extractor import VGGNet
    print("two_vgg_feature_extractor imported successfully!")
except ModuleNotFoundError:
    print("Could not import two_vgg_feature_extractor. Please ensure the file is in the correct Drive folder.")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, None, None, 3)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, None, None, 64) │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, None, None, 64) │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, None, None, 64) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, None, None,     │        73,856 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, None, None,     │       147,584 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, None, None,     │       295,168 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, None, None,     │       590,080 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, None, None,     │       590,080 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, None, None,     │     1,180,160 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling2d            │ (None, 512)            │             0 │
# │ (GlobalMaxPooling2D)            │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)
# two_vgg_feature_extractor imported successfully!

# %%
images_path = os.path.join(module_path, "MBB_results")
img_list = [os.path.join(images_path, f) for f in os.listdir(images_path)]

# %%
print(" start feature extraction")

model = VGGNet()

path = images_path + "/"

feats = []
names = []

for im in os.listdir(path): #iterate through all images to extract features
    print("Extracting features from image - ", im)
    X = model.extract_feat(path + im)

    feats.append(X)
    names.append(im)

feats = np.array(feats)

# directory for storing extracted features
output = "VGG16Features.h5"

print(" writing feature extraction results to h5 file")

if os.path.exists(output):
    os.remove(output)

h5f = h5py.File(output, 'w')
h5f.create_dataset('dataset_1', data = feats)
h5f.create_dataset('dataset_2', data = np.bytes_(names))
h5f.close()
# Out:
#  start feature extraction
# Extracting features from image -  RGB_132_MBB_9e-05.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0001901.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0002902.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0004904.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0003903.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.00069061.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.00059051.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.00089081.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.00099091.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.00079071.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.001091.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0011911.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0012912.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0013913.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0014914.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0015915.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0016916.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0017917.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0018918.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0019919.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.002092.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0021921.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0022922.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0023923.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0024924.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0025925.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0026926.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0027927.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0028928.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0029929.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0031931.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.003093.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0032932.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0033933.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0034934.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0035935.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0036936.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0037937.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0038938.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0039939.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.004094.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0041941.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0042942.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0043943.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0044944.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0045945.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0047947.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0046946.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0048948.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0049949.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0050951.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0052953.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0051952.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0053954.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0054955.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0055956.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0056957.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0057958.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0058959.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.005996.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0060961.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0061962.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0062963.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0063964.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0064965.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0065966.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0066967.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0068969.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0067968.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.006997.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0070971.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0071972.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0072973.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0073974.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0074975.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0075976.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0076977.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0077978.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0078979.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.007998.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0080981.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0082983.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0081982.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0083984.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0084985.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0085986.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0086987.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0087988.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0088989.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.008999.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0090991.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0091992.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0092993.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0093994.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0094995.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0095996.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0096997.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0097998.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.0098999.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Extracting features from image -  RGB_132_MBB_0.01.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
#  writing feature extraction results to h5 file

# %%
import matplotlib.pyplot as plt

# reading features database (h5 file)
h5f = h5py.File("VGG16Features.h5", 'r')
feats = h5f['dataset_1'][:]
imgNames = h5f['dataset_2'][:]
h5f.close()

# %%
# Reading the query image
queryImg = os.path.join(module_path, "query_images/RGB_132_GT.png")
print(" searching for similar images")

# VGGNet16 model
model = VGGNet()

# Extracting Features
X = model.extract_feat(queryImg)

scores = []
from scipy import spatial
for i in range(feats.shape[0]):
    score = 1 - spatial.distance.cosine(X, feats[i])
    scores.append(score)
scores = np.array(scores)
rank_ID = np.argsort(scores)[::-1]
rank_score = scores[rank_ID]


maxres = 3
imlist = [imgNames[index] for i, index in enumerate(rank_ID[0:maxres])]
print("top %d images in order are: " %maxres, imlist)
# Out:
#  searching for similar images
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# top 3 images in order are:  [np.bytes_(b'RGB_132_MBB_0.0015915.png'), np.bytes_(b'RGB_132_MBB_0.0019919.png'), np.bytes_(b'RGB_132_MBB_0.0018918.png')]

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

print("Query Image:")
plt.figure(figsize=(5, 5)) # Creating a new figure for the query image
query_img_display = mpimg.imread(queryImg)

if len(query_img_display.shape) == 2 or query_img_display.shape[2] == 1:
    query_img_display = plt.cm.gray(query_img_display)[:,:,:3] # Converting grayscale to RGB
plt.imshow(query_img_display)
plt.axis('off')
plt.title("Query Image")
plt.show()

# Display the top 3 similar images
print("Top 3 Similar Images:")
for i, img_name_bytes in enumerate(imlist):
    img_name = img_name_bytes.decode('utf-8')
    img_path = os.path.join(images_path, img_name)
    img = mpimg.imread(img_path)

    if len(img.shape) == 2 or img.shape[2] == 1:
        img = plt.cm.gray(img)[:,:,:3]
    plt.figure(figsize=(5, 5))
    plt.imshow(img)
    plt.axis('off')
    plt.title(img_name)
    plt.show()
# Out:
# Query Image:
# Top 3 Similar Images:
